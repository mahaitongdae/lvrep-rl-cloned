# %%
import pandas as pd

from eval_v2_robust import eval_robust

df_robust = eval_robust('/home/mht/PycharmProjects/lvrep-rl-cloned/log/Pendulum-v1_sigma_0.0_rew_scale_1.0/rfsac_nystrom_False_rf_num_512_learn_rf_False/seed_0_2024-02-01-00-08-46')
df_common = eval_robust('/home/mht/PycharmProjects/lvrep-rl-cloned/log/Pendulum-v1_sigma_0.0_rew_scale_1.0/rfsac_nystrom_False_rf_num_512_learn_rf_False/seed_0_2024-02-01-10-45-39')
# Out:
# 0.2
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -85.344 $\pm$ 50.917
# ---------------------------------------
# 0.6000000000000001
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -168.166 $\pm$ 107.920
# ---------------------------------------
# 1.0
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -238.792 $\pm$ 170.411
# ---------------------------------------
# 1.4000000000000001
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -319.277 $\pm$ 247.931
# ---------------------------------------
# 1.8
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -392.411 $\pm$ 323.058
# ---------------------------------------
# 0.2
# ---------------------------------------
# ...

# %%
df_common['algo'] = 'non-robust'
df_robust['algo'] = 'robust'
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.concat([df_common, df_robust], ignore_index=True)
plt.figure(figsize=[10,10])
sns.set(font_scale=3)
sns.lineplot(data=df, x='m', y='rets', hue='algo')
plt.xlabel('mass')
plt.ylabel('expected returns')
# Out:
# Text(0, 0.5, 'expected returns')
