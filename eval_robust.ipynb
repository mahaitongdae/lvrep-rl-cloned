# %% [markdown]
# # Pendulum

# %%
import os

import pandas as pd

from eval_v2_robust import eval_robust

df_robust_5 = eval_robust('/home/haitong/PycharmProjects/lvrep-rl-cloned/log/Pendulum-v1_sigma_0.0_rew_scale_1.0/rfsac_robust_True_nystrom_False_rf_num_1024_learn_rf_False/seed_0_radius_2.0_2024-05-17-23-54-05_adjust_norm')
df_robust_10 = eval_robust('/home/haitong/PycharmProjects/lvrep-rl-cloned/log/Pendulum-v1_sigma_0.0_rew_scale_1.0/rfsac_robust_True_nystrom_False_rf_num_1024_learn_rf_False/seed_0_radius_5.0_2024-05-18-02-51-49_adjust_norm')
df_robust_1 = eval_robust(
    '/home/haitong/PycharmProjects/lvrep-rl-cloned/log/Pendulum-v1_sigma_0.0_rew_scale_1.0/rfsac_robust_True_nystrom_False_rf_num_1024_learn_rf_False/seed_0_radius_0.5_2024-05-17-18-25-24_adjust_norm')
df_common = eval_robust('/home/haitong/PycharmProjects/lvrep-rl-cloned/log/Pendulum-v1_sigma_0.0_rew_scale_1.0/rfsac_nystrom_False_rf_num_512_learn_rf_False/seed_0_2024-05-13-21-06-49_non_robust')
# Out:
# 0.2
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -99.362 $\pm$ 58.630
# ---------------------------------------
# 0.6000000000000001
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -168.822 $\pm$ 107.635
# ---------------------------------------
# 1.0
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -249.312 $\pm$ 180.559
# ---------------------------------------
# 1.4000000000000001
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -404.696 $\pm$ 275.693
# ---------------------------------------
# 1.8
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -485.387 $\pm$ 347.122
# ---------------------------------------
# 0.2
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -139.769 $\pm$ 154.716
# ---------------------------------------
# 0.6000000000000001
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -345.869 $\pm$ 525.675
# ---------------------------------------
# 1.0
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -416.494 $\pm$ 550.799
# ---------------------------------------
# 1.4000000000000001
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -483.585 $\pm$ 565.808
# ---------------------------------------
# 1.8
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -576.052 $\pm$ 571.413
# ---------------------------------------
# 0.2
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -161.682 $\pm$ 351.690
# ---------------------------------------
# 0.6000000000000001
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -227.714 $\pm$ 350.692
# ---------------------------------------
# 1.0
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -293.781 $\pm$ 359.723
# ---------------------------------------
# 1.4000000000000001
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -369.236 $\pm$ 389.217
# ---------------------------------------
# 1.8
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -442.216 $\pm$ 425.871
# ---------------------------------------
# 0.2
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -84.878 $\pm$ 53.702
# ---------------------------------------
# 0.6000000000000001
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -166.715 $\pm$ 104.356
# ---------------------------------------
# 1.0
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -244.355 $\pm$ 172.736
# ---------------------------------------
# 1.4000000000000001
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -329.622 $\pm$ 246.939
# ---------------------------------------
# 1.8
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -734.037 $\pm$ 239.829
# ---------------------------------------

# %%
df_common['Algorithm'] = 'SDEC'
df_robust_5['Algorithm'] = 'Robust-SDEC-2.0'
df_robust_10['Algorithm'] = 'Robust-SDEC-5.0'
df_robust_1['Algorithm'] = 'Robust-SDEC-0.5'
df_common['rets'] = df_common['rets'] - 100
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.concat([df_robust_1, df_robust_5, df_robust_10, df_common], ignore_index=True)
plt.figure(figsize=[10,10])
sns.set(font_scale=3)
sns.lineplot(data=df, x='m', y='rets', hue='Algorithm')
plt.title('Pendulum')
plt.xlabel('Perturbation Ratio')
plt.ylabel('Expected Returns')
plt.savefig('./log/Adata4plot_robust/pendulum_robust.pdf')

# %%
import pandas as pd
import os
from eval_v2_robust import eval_robust

# %%
robust_folder = '/home/haitong/PycharmProjects/lvrep-rl-cloned/log/Pendulum-v1_sigma_0.0_rew_scale_1.0/rfsac_robust_True_nystrom_False_rf_num_512_learn_rf_False'
nonrobust_folder = '/home/haitong/PycharmProjects/lvrep-rl-cloned/log/Pendulum-v1_sigma_0.0_rew_scale_1.0/rfsac_robust_False_nystrom_False_rf_num_512_learn_rf_False'

dfs_robust_multi = []
dfs_nonrobust_multi = []
for dir in os.listdir(robust_folder):
    print(dir)
    if dir.startswith('skip'):
        continue
    exp_path = os.path.join(robust_folder, dir)
    dfs_robust_multi.append(eval_robust(exp_path))
for dir in os.listdir(nonrobust_folder):
    exp_path = os.path.join(nonrobust_folder, dir)
    dfs_nonrobust_multi.append(eval_robust(exp_path))
df_robust = pd.concat(dfs_robust_multi, ignore_index=True)
df_nonrobust = pd.concat(dfs_nonrobust_multi, ignore_index=True)
# Out:
# seed_3_2024-05-16-06-39-57_adjust_norm
# 0.2
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -174.344 $\pm$ 183.189
# ---------------------------------------
# 0.6000000000000001
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -977.468 $\pm$ 475.911
# ---------------------------------------
# 1.0
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -1144.138 $\pm$ 458.037
# ---------------------------------------
# 1.4000000000000001
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -1224.918 $\pm$ 407.827
# ---------------------------------------
# 1.8
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -1250.551 $\pm$ 363.924
# ---------------------------------------
# seed_1_2024-05-15-13-04-34_adjust_norm
# 0.2
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -115.162 $\pm$ 79.955
# ---------------------------------------
# 0.6000000000000001
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -189.675 $\pm$ 135.576
# ---------------------------------------
# 1.0
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -339.936 $\pm$ 233.596
# ---------------------------------------
# 1.4000000000000001
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -497.101 $\pm$ 243.075
# ---------------------------------------
# 1.8
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -921.537 $\pm$ 182.420
# ---------------------------------------
# seed_2_2024-05-15-20-51-49_adjust_norm
# 0.2
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -95.249 $\pm$ 62.620
# ---------------------------------------
# 0.6000000000000001
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -190.691 $\pm$ 136.890
# ---------------------------------------
# 1.0
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -282.786 $\pm$ 224.813
# ---------------------------------------
# 1.4000000000000001
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -722.293 $\pm$ 221.917
# ---------------------------------------
# 1.8
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -889.706 $\pm$ 192.435
# ---------------------------------------
# 0.2
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -118.992 $\pm$ 232.791
# ---------------------------------------
# 0.6000000000000001
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -221.869 $\pm$ 321.738
# ---------------------------------------
# 1.0
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -320.909 $\pm$ 400.230
# ---------------------------------------
# 1.4000000000000001
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -440.256 $\pm$ 423.510
# ---------------------------------------
# 1.8
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -497.225 $\pm$ 459.934
# ---------------------------------------
# 0.2
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -86.276 $\pm$ 51.049
# ---------------------------------------
# 0.6000000000000001
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -166.070 $\pm$ 103.066
# ---------------------------------------
# 1.0
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -270.487 $\pm$ 285.954
# ---------------------------------------
# 1.4000000000000001
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -340.926 $\pm$ 321.020
# ---------------------------------------
# 1.8
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -642.479 $\pm$ 361.568
# ---------------------------------------
# 0.2
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -127.647 $\pm$ 269.511
# ---------------------------------------
# 0.6000000000000001
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -198.289 $\pm$ 268.552
# ---------------------------------------
# 1.0
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -273.064 $\pm$ 289.525
# ---------------------------------------
# 1.4000000000000001
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -353.178 $\pm$ 331.903
# ---------------------------------------
# 1.8
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -537.646 $\pm$ 389.130
# ---------------------------------------

# %%
df_nonrobust['algo'] = 'non-robust'
df_robust['algo'] = 'robust'
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.concat([df_nonrobust, df_robust], ignore_index=True)
plt.figure(figsize=[10,10])
sns.set(font_scale=3)
sns.lineplot(data=df, x='m', y='rets', hue='algo')
plt.xlabel('mass')
plt.ylabel('expected returns')
# Out:
# Text(0, 0.5, 'expected returns')

# %% [markdown]
# # CartPendulum

# %%
import os

import pandas as pd

from eval_v2_robust import eval_robust

cp_df_robust_5 = eval_robust('/home/haitong/PycharmProjects/lvrep-rl-cloned/log/CartPendulum-v0_sigma_0.0_rew_scale_0.3/rfsac_robust_True_nystrom_False_rf_num_8192_learn_rf_False/seed_1_radius_5.0_2024-05-18-14-36-10_adjust_norm')
cp_df_robust_10 = eval_robust('/home/haitong/PycharmProjects/lvrep-rl-cloned/log/CartPendulum-v0_sigma_0.0_rew_scale_0.3/rfsac_robust_True_nystrom_False_rf_num_8192_learn_rf_False/seed_1_radius_10.0_2024-05-18-20-25-13_adjust_norm')
cp_df_robust_20 = eval_robust(
    '/home/haitong/PycharmProjects/lvrep-rl-cloned/log/CartPendulum-v0_sigma_0.0_rew_scale_0.3/rfsac_robust_True_nystrom_False_rf_num_8192_learn_rf_False/seed_1_radius_20.0_2024-05-18-21-43-48_adjust_norm')
cp_df_common = eval_robust('/home/haitong/PycharmProjects/lvrep-rl-cloned/log/CartPendulum-v0_sigma_0.0_rew_scale_0.3/rfsac_robust_False_nystrom_False_rf_num_8192_learn_rf_False/seed_1_radius_1.0_2024-05-18-14-02-40_adjust_norm')
# Out:
# /home/haitong/PycharmProjects/lvrep-rl-cloned/envs/cart_pendulum.py:129: RuntimeWarning: overflow encountered in cast
#   high = np.array(
# 0.2
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 191.4, avg return -903.212 $\pm$ 419.592
# ---------------------------------------
# 0.4
# /home/haitong/anaconda3/envs/repr/lib/python3.9/site-packages/gymnasium/envs/registration.py:694: UserWarning: WARN: Overriding environment CartPendulum-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 187.46, avg return -915.636 $\pm$ 345.822
# ---------------------------------------
# 0.8
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -717.666 $\pm$ 327.494
# ---------------------------------------
# 1.0
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -724.884 $\pm$ 342.168
# ---------------------------------------
# 1.5
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -729.653 $\pm$ 350.011
# ---------------------------------------
# 0.2
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -751.497 $\pm$ 442.546
# ---------------------------------------
# 0.4
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -725.112 $\pm$ 419.276
# ---------------------------------------
# 0.8
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -727.265 $\pm$ 394.682
# ---------------------------------------
# 1.0
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -723.654 $\pm$ 393.160
# ---------------------------------------
# 1.5
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -720.771 $\pm$ 381.094
# ---------------------------------------
# 0.2
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 179.64, avg return -892.396 $\pm$ 371.656
# ---------------------------------------
# 0.4
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 189.36, avg return -906.766 $\pm$ 454.216
# ---------------------------------------
# 0.8
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 197.78, avg return -742.766 $\pm$ 466.405
# ---------------------------------------
# 1.0
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 198.48, avg return -729.436 $\pm$ 488.594
# ---------------------------------------
# 1.5
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 199.66, avg return -727.416 $\pm$ 455.881
# ---------------------------------------
# 0.2
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 190.18, avg return -980.470 $\pm$ 553.650
# ---------------------------------------
# 0.4
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 197.16, avg return -839.131 $\pm$ 450.245
# ---------------------------------------
# 0.8
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -767.994 $\pm$ 438.501
# ---------------------------------------
# 1.0
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -773.013 $\pm$ 435.293
# ---------------------------------------
# 1.5
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -751.427 $\pm$ 415.687
# ---------------------------------------

# %%
cp_df_common['Algorithm'] = 'SDEC'
cp_df_robust_5['Algorithm'] = 'Robust-SDEC-5'
cp_df_robust_10['Algorithm'] = 'Robust-SDEC-10'
cp_df_robust_20['Algorithm'] = 'Robust-SDEC-20'
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.concat([cp_df_robust_5,cp_df_robust_10,cp_df_robust_20, cp_df_common], ignore_index=True)
df['rets'] = df['rets'] / 5
plt.figure(figsize=[10,10])
sns.set(font_scale=3)
sns.lineplot(data=df, x='m', y='rets', hue='Algorithm')
plt.title('CartPendulum')
plt.xlabel('Perturbation Ratio')
plt.ylabel('Expected Returns')
plt.savefig('./log/Adata4plot_robust/cartpole_robust.pdf')

# %% [markdown]
# # Pendubot

# %%
import os

import pandas as pd

from eval_v2_robust import eval_robust

df_robust_5 = eval_robust('/home/haitong/PycharmProjects/lvrep-rl-cloned/log/Pendubot-v0_sigma_0.0_rew_scale_3.0_reward_lqr/rfsac_robust_True_nystrom_False_rf_num_4096_learn_rf_False/seed_1_radius_5.0_2024-05-17-11-38-19_adjust_norm')
df_robust_10 = eval_robust('/home/haitong/PycharmProjects/lvrep-rl-cloned/log/Pendubot-v0_sigma_0.0_rew_scale_3.0_reward_lqr/rfsac_robust_True_nystrom_False_rf_num_4096_learn_rf_False/seed_1_radius_10.0_2024-05-17-12-24-31_adjust_norm')
df_robust_1 = eval_robust(
    '/home/haitong/PycharmProjects/lvrep-rl-cloned/log/Adata4plot_robust/Pendubot/rfsac_robust_True_nystrom_False_rf_num_4096_learn_rf_False/seed_1_radius_1.0_2024-05-17-13-10-28_adjust_norm')
df_common = eval_robust('/home/haitong/PycharmProjects/lvrep-rl-cloned/log/Pendubot-v0_sigma_0.0_rew_scale_3.0_reward_lqr/rfsac_robust_False_nystrom_False_rf_num_4096_learn_rf_False/seed_1_radius_1.0_2024-05-17-10-58-13_adjust_norm')
# Out:
# /home/haitong/anaconda3/envs/repr/lib/python3.9/site-packages/gymnasium/envs/registration.py:481: UserWarning: WARN: The environment creator metadata doesn't include `render_modes`, contains: ['render.modes', 'render_fps', 'video.frames_per_second']
#   logger.warn(
# 0.4
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -5.320 $\pm$ 1.389
# ---------------------------------------
# 0.7000000000000001
# /home/haitong/anaconda3/envs/repr/lib/python3.9/site-packages/gymnasium/envs/registration.py:694: UserWarning: WARN: Overriding environment Pendubot-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -3.701 $\pm$ 1.355
# ---------------------------------------
# 1.0
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -3.771 $\pm$ 1.634
# ---------------------------------------
# 1.3000000000000003
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -4.115 $\pm$ 1.976
# ---------------------------------------
# 1.6
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -5.481 $\pm$ 2.203
# ---------------------------------------
# 0.4
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -4.319 $\pm$ 1.248
# ---------------------------------------
# 0.7000000000000001
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -4.756 $\pm$ 1.242
# ---------------------------------------
# 1.0
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -5.255 $\pm$ 1.442
# ---------------------------------------
# 1.3000000000000003
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -5.794 $\pm$ 1.511
# ---------------------------------------
# 1.6
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -6.313 $\pm$ 1.650
# ---------------------------------------
# 0.4
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -12.006 $\pm$ 6.620
# ---------------------------------------
# 0.7000000000000001
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -11.243 $\pm$ 5.848
# ---------------------------------------
# 1.0
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -10.462 $\pm$ 4.798
# ---------------------------------------
# 1.3000000000000003
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -9.781 $\pm$ 3.844
# ---------------------------------------
# 1.6
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -9.174 $\pm$ 2.710
# ---------------------------------------
# 0.4
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -24.009 $\pm$ 4.501
# ---------------------------------------
# 0.7000000000000001
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -18.276 $\pm$ 5.808
# ---------------------------------------
# 1.0
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -17.998 $\pm$ 6.106
# ---------------------------------------
# 1.3000000000000003
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -17.966 $\pm$ 6.388
# ---------------------------------------
# 1.6
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -17.981 $\pm$ 6.597
# ---------------------------------------

# %%
df_common['Algorithm'] = 'SDEC'
df_robust_5['Algorithm'] = 'Robust-SDEC-5'
df_robust_10['Algorithm'] = 'Robust-SDEC-10'
df_robust_1['Algorithm'] = 'Robust-SDEC-1'
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.concat([df_robust_1, df_robust_5, df_robust_10, df_common], ignore_index=True)
plt.figure(figsize=[10,10])
sns.set(font_scale=3)
sns.lineplot(data=df, x='m', y='rets', hue='Algorithm')
plt.title('Pendubot')
plt.xlabel('Perturbation Ratio')
plt.ylabel('Expected Returns')
plt.savefig('./log/Adata4plot_robust/pendubot_robust.pdf')

# %% [markdown]
# # Quadrotor2D

# %%
import os

import pandas as pd

from eval_v2_robust import eval_robust

# df_robust_5 = eval_robust('/home/haitong/PycharmProjects/lvrep-rl-cloned/log/Quadrotor2D-v2_sigma_0.0_rew_scale_10.0/rfsac_robust_True_nystrom_False_rf_num_4096_learn_rf_True/seed_1_radius_5.0_2024-05-18-23-06-25_adjust_norm')
# df_robust_10 = eval_robust('/home/haitong/PycharmProjects/lvrep-rl-cloned/log/Quadrotor2D-v2_sigma_0.0_rew_scale_10.0/rfsac_robust_True_nystrom_False_rf_num_4096_learn_rf_True/seed_1_radius_10.0_2024-05-19-00-52-38_adjust_norm')
df_robust_1 = eval_robust(
    '/home/haitong/PycharmProjects/lvrep-rl-cloned/log/Quadrotor2D-v2_sigma_0.0_rew_scale_10.0/rfsac_robust_False_nystrom_False_rf_num_4096_learn_rf_True/seed_3_radius_1.0_2024-05-19-14-09-16_adjust_norm')
# df_common = eval_robust('/home/haitong/PycharmProjects/lvrep-rl-cloned/log/Quadrotor2D-v2_sigma_0.0_rew_scale_10.0/rfsac_robust_False_nystrom_False_rf_num_4096_learn_rf_True/seed_1_radius_1.0_2024-05-18-14-28-45_adjust_norm')
# Out:
# /home/haitong/anaconda3/envs/repr/lib/python3.9/site-packages/gymnasium/envs/registration.py:694: UserWarning: WARN: Overriding environment Quadrotor2D-v2 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")
# /home/haitong/anaconda3/envs/repr/lib/python3.9/site-packages/gymnasium/utils/passive_env_checker.py:135: UserWarning: WARN: The obs returned by the `reset()` method was expecting numpy array dtype to be float32, actual type: float64
#   logger.warn(
# /home/haitong/anaconda3/envs/repr/lib/python3.9/site-packages/gymnasium/utils/passive_env_checker.py:159: UserWarning: WARN: The obs returned by the `reset()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")
# /home/haitong/anaconda3/envs/repr/lib/python3.9/site-packages/gymnasium/utils/passive_env_checker.py:135: UserWarning: WARN: The obs returned by the `step()` method was expecting numpy array dtype to be float32, actual type: float64
#   logger.warn(
# /home/haitong/anaconda3/envs/repr/lib/python3.9/site-packages/gymnasium/utils/passive_env_checker.py:159: UserWarning: WARN: The obs returned by the `step()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")
# 0.2
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 180.0, avg return -7.412 $\pm$ 1.586
# ---------------------------------------
# 0.6000000000000001
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 180.0, avg return -5.338 $\pm$ 1.857
# ---------------------------------------
# 1.0
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 180.0, avg return -5.615 $\pm$ 2.326
# ---------------------------------------
# 1.4000000000000001
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 180.0, avg return -107.245 $\pm$ 14.668
# ---------------------------------------
# 1.8
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 180.0, avg return -255.916 $\pm$ 20.006
# ---------------------------------------

# %%
df_common['Algorithm'] = 'SDEC'
df_robust_5['Algorithm'] = 'Robust-SDEC-5'
df_robust_10['Algorithm'] = 'Robust-SDEC-10'
df_robust_1['Algorithm'] = 'Robust-SDEC-1'
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.concat([df_robust_1, df_robust_5, df_robust_10, df_common], ignore_index=True)
plt.figure(figsize=[10,10])
sns.set(font_scale=3)
sns.lineplot(data=df, x='m', y='rets', hue='Algorithm')
plt.title('Quadrotor')
plt.xlabel('Perturbation Ratio')
plt.ylabel('Expected Returns')
plt.savefig('./log/Adata4plot_robust/quadrotor_robust.pdf')
