# %%
import os

import pandas as pd

from eval_v2_robust import eval_robust

df_robust = eval_robust('/home/haitong/PycharmProjects/lvrep-rl-cloned/log/Pendulum-v1_sigma_0.0_rew_scale_1.0/rfsac_nystrom_False_rf_num_512_learn_rf_False/seed_0_2024-05-13-21-57-05_adjust_norm')
# df_common = eval_robust('/home/haitong/PycharmProjects/lvrep-rl-cloned/log/Pendulum-v1_sigma_0.0_rew_scale_1.0/rfsac_nystrom_False_rf_num_512_learn_rf_False/seed_0_2024-05-13-21-06-49_non_robust')
# Out:
# 0.2
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -115.799 $\pm$ 131.377
# ---------------------------------------
# 0.6000000000000001
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -168.711 $\pm$ 106.369
# ---------------------------------------
# 1.0
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -247.098 $\pm$ 175.450
# ---------------------------------------
# 1.4000000000000001
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -376.730 $\pm$ 251.527
# ---------------------------------------
# 1.8
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -563.124 $\pm$ 276.443
# ---------------------------------------

# %%
df_common['algo'] = 'non-robust'
df_robust['algo'] = 'robust'
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.concat([df_common, df_robust], ignore_index=True)
plt.figure(figsize=[10,10])
sns.set(font_scale=3)
sns.lineplot(data=df, x='m', y='rets', hue='algo')
plt.xlabel('mass')
plt.ylabel('expected returns')
# Out:
# Text(0, 0.5, 'expected returns')

# %%
import pandas as pd
import os
from eval_v2_robust import eval_robust

robust_folder = '/home/haitong/PycharmProjects/lvrep-rl-cloned/log/Pendulum-v1_sigma_1.0_rew_scale_1.0/rfsac_True_nystrom_False_rf_num_512_learn_rf_False'
nonrobust_folder = '/home/haitong/PycharmProjects/lvrep-rl-cloned/log/Pendulum-v1_sigma_1.0_rew_scale_1.0/rfsac_False_nystrom_False_rf_num_512_learn_rf_False'

dfs_robust_multi = []
dfs_nonrobust_multi = []
for dir in os.listdir(robust_folder):
    print(dir)
    if dir.startswith('skip'):
        continue
    exp_path = os.path.join(robust_folder, dir)
    dfs_robust_multi.append(eval_robust(exp_path))
# for dir in os.listdir(nonrobust_folder):
#     exp_path = os.path.join(nonrobust_folder, dir)
#     dfs_nonrobust_multi.append(eval_robust(exp_path))
df_robust = pd.concat(dfs_robust_multi, ignore_index=True)
# df_nonrobust = pd.concat(dfs_nonrobust_multi, ignore_index=True)
# Out:
# seed_1_2024-05-14-10-50-12_adjust_norm
# 0.2
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -170.425 $\pm$ 369.187
# ---------------------------------------
# 0.6000000000000001
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -287.466 $\pm$ 364.109
# ---------------------------------------
# 1.0
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -659.959 $\pm$ 292.250
# ---------------------------------------
# 1.4000000000000001
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -747.672 $\pm$ 290.991
# ---------------------------------------
# 1.8
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -786.292 $\pm$ 298.559
# ---------------------------------------
# skip_seed_2_2024-05-14-11-30-36_adjust_norm
# skip_seed_4_2024-05-14-12-49-13_adjust_norm
# seed_3_2024-05-14-12-10-08_adjust_norm
# 0.2
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -95.404 $\pm$ 56.780
# ---------------------------------------
# 0.6000000000000001
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -169.112 $\pm$ 105.655
# ---------------------------------------
# 1.0
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -302.452 $\pm$ 191.860
# ---------------------------------------
# 1.4000000000000001
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -604.611 $\pm$ 186.247
# ---------------------------------------
# 1.8
# ---------------------------------------
# Evaluation over 50 episodes: avg eplen 200.0, avg return -705.938 $\pm$ 216.994
# ---------------------------------------

# %%
df_nonrobust['algo'] = 'non-robust'
df_robust['algo'] = 'robust'
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.concat([df_nonrobust, df_robust], ignore_index=True)
plt.figure(figsize=[10,10])
sns.set(font_scale=3)
sns.lineplot(data=df, x='m', y='rets', hue='algo')
plt.xlabel('mass')
plt.ylabel('expected returns')
# Out:
# Text(0, 0.5, 'expected returns')
