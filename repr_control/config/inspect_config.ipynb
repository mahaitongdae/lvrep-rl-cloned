# %%
import yaml

# %%
with open("map1.yaml", "r") as stream:
    try:
        config = yaml.safe_load(stream)
    except yaml.YAMLError as exc:
        print(exc)
        
config['tasks']['forward_left']
# Out:
# {'init': {'min': [20.0, -20.0, 1.5707963267948966],
#   'max': [20.0, -5.0, 1.5707963267948966]},
#  'goal': {'min': [4.0, 0.0, 3.141592653589793],
#   'max': [12.0, 0.0, 3.141592653589793]}}
