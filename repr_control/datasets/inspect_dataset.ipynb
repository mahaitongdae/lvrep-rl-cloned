# %%
from repr_control.datasets.datasets import SupervisedParkingDataset
import torch
from torch.utils.data import DataLoader

# %%
dataset = torch.load('/home/naliseas-workstation/Documents/haitong/repr_control/lvrep-rl-cloned/repr_control/datasets/data/2025-04-26_12-27-52/1_1.000_500_12.000.pt')

# %%
loader = DataLoader(dataset, batch_size=10, shuffle=False)
for l in loader:
    print(l)
    break
# Out:
# [tensor([[-1.2000e+01,  2.0000e+01, -1.5708e+00,  0.0000e+00,  0.0000e+00,
#           0.0000e+00, -1.2000e+01,  2.0000e+01, -1.5708e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00,  1.2000e+01],
#         [-1.2000e+01,  2.0000e+01, -1.5708e+00,  9.2137e-30,  2.0000e-01,
#           2.6180e-02, -1.2000e+01,  2.0000e+01, -1.5708e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00,  1.2000e+01],
#         [-1.2000e+01,  1.9980e+01, -1.5707e+00, -1.0628e-04,  4.0000e-01,
#           5.2360e-02, -1.2000e+01,  2.0000e+01, -1.5708e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00,  1.2000e+01],
#         [-1.2000e+01,  1.9940e+01, -1.5703e+00, -5.3135e-04,  6.0000e-01,
#           7.8539e-02, -1.2000e+01,  2.0000e+01, -1.5708e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00,  1.2000e+01],
#         [-1.2000e+01,  1.9880e+01, -1.5693e+00, -1.4870e-03,  8.0000e-01,
#           1.0359e-01, -1.2000e+01,  2.0000e+01, -1.5708e+00,  0.0000e+00,
# ...

# %%
from repr_control.envs.models.articulate_model_cstr import initial_distribution
initial_distribution(5).numpy().shape
# Out:
# (5, 45)

# %% [markdown]
# # Loader
