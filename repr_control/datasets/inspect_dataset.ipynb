# %%
from repr_control.datasets.datasets import SupervisedParkingDataset
import torch
from torch.utils.data import DataLoader

# %%
dataset = torch.load('/Users/mahaitong/Dropbox (Harvard University)/backup1204/repr_control/repr_control/datasets/2025-04-18_00-51-08/2_1.000_2000_15.000.pt')

# %%
loader = DataLoader(dataset, batch_size=1, shuffle=False)
for l in loader:
    print(l)
    break
# Out:
# [tensor([[-40.0000,   0.0000,  -1.5708,   0.0000,   0.0000,   0.0000, -40.0000,
#            0.0000,  -1.5708,   0.0000,   0.0000,   0.0000,  15.0000]],
#        dtype=torch.float64), tensor([[-1.0000,  1.0000]], dtype=torch.float64)]

# %% [markdown]
# # Loader
